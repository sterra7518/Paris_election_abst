# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1 - Européennes 2024

# %%
# Ouverture des fichiers 

eur24 = pd.read_csv("res_europeennes_24.csv",sep=";",encoding="ISO-8859-1")


eur24 = eur24.rename(columns = {"ï»¿id_bv":"id_bv"})

eur24 = eur24.set_index('id_bv',drop='True')


eur24
# Out:
#        nb_procu taux_procu  nb_inscr  nb_abscent taux_abst  nb_emarg  \
# id_bv
# 01_01        37     0,0337      1099         456    0,4149       643
# 01_02        59     0,0479      1232         537    0,4359       695
# 01_03        56     0,0457      1225         468     0,382       756
# 01_04        48     0,0366      1310         569    0,4344       741
# 01_05        48      0,044      1090         444    0,4073       647
# ...         ...        ...       ...         ...       ...       ...
# 20_72        66     0,0374      1763         785    0,4453       978
# 20_73         0          0      1747         657    0,3761      1090
# 20_74       110      0,062      1775         634    0,3572      1141
# 20_75        59     0,0315      1871         979    0,5232       892
# 20_76        92     0,0431      2136        1009    0,4724      1127
#
#        nb_votant  nb_bl  nb_nul  nb_exprim  NB_ExtGauche  NB_Gauche  \
# id_bv
# 01_01        643      1       3        639             2        293
# 01_02        695      4       5        686             1        328
# 01_03        757      3       6        748             3        366
# 01_04        741      0       9        732             4        386
# 01_05        646      2       0        644             1        337
# ...          ...    ...     ...        ...           ...        ...
# 20_72        978      7       5        966            10        735
# 20_73       1090      3       1       1086            11        848
# 20_74       1141      4       5       1132             3        913
# 20_75        892      4       9        879            13        673
# 20_76       1127      2       7       1118             7        885
#
#        NB_Centre  NB_Droite  NB_ExtDroite  NB_Divers  voix_Gauche  voix_Droite
# id_bv
# 01_01        144         74           114         12          295          188
# 01_02        193         56            98         10          329          154
# 01_03        177         58           125         19          369          183
# 01_04        146         52           123         21          390          175
# 01_05        149         47           106          4          338          153
# ...          ...        ...           ...        ...          ...          ...
# 20_72         75         38            95         13          745          133
# 20_73        102         31            88          6          859          119
# 20_74         94         33            73         16          916          106
# 20_75         57         33            92         11          686          125
# 20_76         86         33            91         16          892          124
#
# [902 rows x 18 columns]

# %%
eur24.columns
# Out:
# Index(['nb_procu', 'taux_procu', 'nb_inscr', 'nb_abscent', 'taux_abst',
#        'nb_emarg', 'nb_votant', 'nb_bl', 'nb_nul', 'nb_exprim', 'NB_ExtGauche',
#        'NB_Gauche', 'NB_Centre', 'NB_Droite', 'NB_ExtDroite', 'NB_Divers',
#        'voix_Gauche', 'voix_Droite'],
#       dtype='object')

# %%
#Nombre totale des abscent aux votes 
abst_eur = np.sum(eur24['nb_abstent'])

#Nombre totales d'inscrit 
insc_eur = np.sum(eur24['nb_inscr']) 


#taux de personnes abscent 
tx_abst_eur = round(abst_eur/insc_eur,3)

res_abst_eur = [insc_eur,abst_eur,tx_abst_eur]
res_abst_eur
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Documents\Downloads\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'nb_abstent'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 2
#       1 #Nombre totale des abscent aux votes
# ----> 2 abst_eur = np.sum(eur24['nb_abstent'])
#       4 #Nombre totales d'inscrit
#       5 insc_eur = np.sum(eur24['nb_inscr'])
#
# File ~\Documents\Downloads\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\Documents\Downloads\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'nb_abstent'

# %%
# Resultats des parties 

partie_eur = [np.sum(eur24['NB_ExtGauche']),
              np.sum(eur24['NB_Gauche']),
              np.sum(eur24['NB_Centre']),
              np.sum(eur24['NB_Droite']),
              np.sum(eur24['NB_ExtDroite']),
              np.sum(eur24['NB_Divers'])]

partie_eur
# Out:
# [3651, 426848, 155179, 88577, 129250, 11072]

# %%
#Diagramme circulaire
plt.figure(figsize=(10,6))

plt.pie(partie_eur,labels = ["Extrême Gauche","Gauche","Centre","Droite","Extrême Droite","Divers"], autopct = '%.2f%%')
plt.title('Nombre de vote par tendance politiques Européennes 24')
plt.savefig("eur24_res_parties.png")

plt.show()

# %% [markdown]
# # 2 -  Résultats legislatives 2024

# %%
#Ouverture du fichier 

leg24 = pd.read_csv("res_legislatives_24.csv",sep=";",encoding="ISO-8859-1")


leg24 = leg24.rename(columns = {"ï»¿id_bv":"id_bv"})

leg24 = leg24.set_index('id_bv',drop='True')


leg24
# Out:
#        num_circo  nb_procu  nb_inscr  nb_emarg  nb_votant  nb_bl  nb_nul  \
# id_bv
# 01_01          1       129      1080       781        781      7       1
# 01_02          1       137      1211       904        904      5       4
# 01_03          1       140      1211       874        874      3       5
# 01_04          1       133      1295       912        912      7       5
# 01_05          1       145      1077       823        823      3       2
# ...          ...       ...       ...       ...        ...    ...     ...
# 20_72          6       196      1746      1229       1230     14       7
# 20_73          6       194      1712      1306       1306     11       6
# 20_74          6       233      1760      1348       1347     19       8
# 20_75          6       100      1864      1212       1212     15      21
# 20_76          6       193      2117      1428       1433     10       9
#
#        nb_exprim  NB_ExtGauche  NB_Gauche  NB_Centre  NB_Droite  NB_ExtDroite  \
# id_bv
# 01_01        773             3        279        324         70            96
# 01_02        895             0        312        414         73            91
# 01_03        866             8        315        346         65           130
# 01_04        900            18        416        315         45           106
# 01_05        818             1        320        356         56            82
# ...          ...           ...        ...        ...        ...           ...
# 20_72       1209            12        904        174         40            79
# 20_73       1289            12        923        250         29            75
# 20_74       1320            15        978        229         23            75
# 20_75       1176            17        881        163         30            85
# 20_76       1414            10       1084        205         33            82
#
#        NB_Divers
# id_bv
# 01_01          1
# 01_02          5
# 01_03          2
# 01_04          0
# 01_05          3
# ...          ...
# 20_72          0
# 20_73          0
# 20_74          0
# 20_75          0
# 20_76          0
#
# [901 rows x 14 columns]

# %%
# Analyser les partipants à l'élection


#Nombre totale des abscent aux votes 
abst_leg = np.sum(leg24["nb_inscr"]) - np.sum(eur24['nb_votant'])

#Nombre totales d'inscrit 
insc_leg = np.sum(leg24['nb_inscr']) 


#taux de personnes abscent 
tx_abst_leg = round(abst_leg/insc_leg,3)

res_abst_leg = [insc_leg,abst_leg,tx_abst_leg]

res_abst_leg
# Out:
# [1364189, 541445, 0.397]

# %%
# Resultats des parties 

partie_leg = [np.sum(leg24['NB_ExtGauche']),
              np.sum(leg24['NB_Gauche']),
              np.sum(leg24['NB_Centre']),
              np.sum(leg24['NB_Droite']),
              np.sum(leg24['NB_ExtDroite']),
              np.sum(leg24['NB_Divers'])]

partie_leg
# Out:
# [5562, 452594, 326406, 83013, 118510, 1260]

# %%
#Diagramme circulaire
plt.figure(figsize=(10,6))

plt.pie(partie_leg,labels = ["Extrême Gauche","Gauche","Centre","Droite","Extrême Droite","Divers"], autopct = '%.2f%%')
plt.title('Nombre de vote par tendance politiques Législatives 24')
plt.savefig("leg24_res_parties.png")

plt.show()

# %% [markdown]
# # 3 - Comparaison des 2 éléctions
#
# ### Taux de participation/Abstention

# %%
#taux d'abstention aux éuropéennes

res_abst_eur
# Out:
# [1378929, 556185, 0.403]

# %%
#taux d'abstention aux législatives

res_abst_leg
# Out:
# [1364189, 541445, 0.397]

# %% [markdown]
# #### Européennes 2024

# %%
eur24.columns
# Out:
# Index(['nb_procu', 'taux_procu', 'nb_inscr', 'nb_abscent', 'taux_abst',
#        'nb_emarg', 'nb_votant', 'nb_bl', 'nb_nul', 'nb_exprim', 'NB_ExtGauche',
#        'NB_Gauche', 'NB_Centre', 'NB_Droite', 'NB_ExtDroite', 'NB_Divers',
#        'voix_Gauche', 'voix_Droite'],
#       dtype='object')

# %%
part_eur = [np.sum(eur24["nb_abscent"]),np.sum(eur24["nb_bl"])+np.sum(eur24["nb_nul"]),np.sum(eur24["nb_exprim"])]

part_eur
# Out:
# [556185, 8167, 814577]

# %%
#diagramme circulaire européennes 2024

plt.figure(figsize=(10,6))

plt.pie(part_eur,labels = ["abscent","blanc et null ","exprimé"],colors = ["grey","yellow","green"] ,autopct = '%.2f%%')
plt.title("Taux d'abscention européennes 24")
plt.savefig("eur24_abs.png")

plt.show()

# %% [markdown]
# #### législative 2024

# %%
leg24.columns
# Out:
# Index(['num_circo', 'nb_procu', 'nb_inscr', 'nb_emarg', 'nb_votant', 'nb_bl',
#        'nb_nul', 'nb_exprim', 'NB_ExtGauche', 'NB_Gauche', 'NB_Centre',
#        'NB_Droite', 'NB_ExtDroite', 'NB_Divers'],
#       dtype='object')

# %%
# Taux d'abstention législative

res_abst_leg
# Out:
# [1364189, 541445, 0.397]

# %%
part_leg = [541445,(np.sum(leg24["nb_bl"])+np.sum(leg24["nb_nul"])),np.sum(leg24["nb_exprim"])]

part_leg
# Out:
# [541445, 12543, 987423]

# %%
#diagramme circulaire européennes 2024

plt.figure(figsize=(10,6))

plt.pie(part_leg,labels = ["abscent","blanc et null ","exprimé"],colors = ["grey","yellow","green"] ,autopct = '%.2f%%')
plt.title("Taux d'abscention législative 24")
plt.savefig("leg24_abs.png")

plt.show()

# %% [markdown]
# #### Dynamique des votes
#
#
# On va comparer les nombres de votes entre les deux éléctions pour chaque tendances politiques

# %%
#comparaisoon


comparaison_pol = [np.sum(leg24["NB_ExtGauche"])-np.sum(eur24["NB_ExtGauche"]),
                   np.sum(leg24["NB_Gauche"])-np.sum(eur24["NB_Gauche"]),
                   np.sum(leg24["NB_Centre"])-np.sum(eur24["NB_Centre"]),
                   np.sum(leg24["NB_Droite"])-np.sum(eur24["NB_Droite"]),
                   np.sum(leg24["NB_ExtDroite"])-np.sum(eur24["NB_ExtDroite"]),
                   np.sum(leg24["NB_Divers"])-np.sum(eur24["NB_Divers"])]

comparaison_pol
# Out:
# [1911, 25746, 171227, -5564, -10740, -9812]

# %% [markdown]
#     + 3289 voix pour l'extrême gauche
#     + 211924 voix pour la gauche
#     + 171227 voix pour le centre
#     - 2453 voix pour la droite
#     - 13654 voix pour l'extrême droite
#     - 10041 voix pour les divers parties

# %%
plt.figure(figsize=(12,6))

names = ['Extrême Gauche','Gauche','Centre','Droite','Extrême Droite','Divers']



plt.bar(names,comparaison_pol,color = ['darkred','red','yellow','royalblue','midnightblue','grey']) 
plt.title("Ecart de voix entre 2 élections de 2024 par tendance politiques")

plt.show()

# %% [markdown]
# # 4 - analyse des abstention
#
# On va analyser les distribution des taux d'abstention par bureau de vote avec les boites à moustache

# %%
# distribution 

leg24["nb_abscent"] = leg24["nb_inscr"] - leg24["nb_votant"]


abst_leg24 = pd.DataFrame(leg24["nb_abscent"])

abst_leg24
# Out:
#        nb_abscent
# id_bv
# 01_01         299
# 01_02         307
# 01_03         337
# 01_04         383
# 01_05         254
# ...           ...
# 20_72         516
# 20_73         406
# 20_74         413
# 20_75         652
# 20_76         684
#
# [901 rows x 1 columns]

# %%
# distribution 

plt.subplot(1, 2, 1)
sns.boxplot(eur24["nb_abscent"])
plt.ylim(100,1200)
plt.title("Européennes 2024")


plt.subplot(1, 2, 2)
sns.boxplot(abst_leg24,color="green")
plt.ylim(100,1200)
plt.title("Législatives 2024")


plt.show()

# %% [markdown]
# On remarque une forte baisse des personnes qui ne sont pas allés votés et d'parès les comparaison on a vu avec les nombres voix , on a une forte mobilisation des résultats

# %% [markdown]
# #### Ecart entre les bureaux de vote

# %%
abst_leg24

abst_leg24 = abst_leg24.rename(columns = {'nb_abscent':'abs_leg'})

abst_leg24
# Out:
#        abs_leg
# id_bv
# 01_01      299
# 01_02      307
# 01_03      337
# 01_04      383
# 01_05      254
# ...        ...
# 20_72      516
# 20_73      406
# 20_74      413
# 20_75      652
# 20_76      684
#
# [901 rows x 1 columns]

# %%
abst_eur24 = pd.DataFrame(eur24["nb_abscent"])

abst_eur24 = abst_eur24.rename(columns = {"nb_abscent":"abs_eur"})

abst_eur24
# Out:
#        abs_eur
# id_bv
# 01_01      456
# 01_02      537
# 01_03      468
# 01_04      569
# 01_05      444
# ...        ...
# 20_72      785
# 20_73      657
# 20_74      634
# 20_75      979
# 20_76     1009
#
# [902 rows x 1 columns]

# %%
#Fusion des deux tables 

abst = abst_eur24.merge(abst_leg24,on="id_bv")

abst
# Out:
#        abs_eur  abs_leg
# id_bv
# 01_01      456      299
# 01_02      537      307
# 01_03      468      337
# 01_04      569      383
# 01_05      444      254
# ...        ...      ...
# 20_72      785      516
# 20_73      657      406
# 20_74      634      413
# 20_75      979      652
# 20_76     1009      684
#
# [901 rows x 2 columns]

# %%
abst["écart"] = abst["abs_eur"] - abst["abs_leg"]

abst
# Out:
#        abs_eur  abs_leg  écart
# id_bv
# 01_01      456      299    157
# 01_02      537      307    230
# 01_03      468      337    131
# 01_04      569      383    186
# 01_05      444      254    190
# ...        ...      ...    ...
# 20_72      785      516    269
# 20_73      657      406    251
# 20_74      634      413    221
# 20_75      979      652    327
# 20_76     1009      684    325
#
# [901 rows x 3 columns]

# %%
# distribution des écart d'abstention 

sns.boxplot(abst["écart"],color="green")
plt.ylim(50,500)
plt.title("distribution des écarts des abscents entre 2 élections")

plt.show()
